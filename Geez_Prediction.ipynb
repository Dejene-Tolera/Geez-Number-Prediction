# %% [markdown]
# #WOLKITE UNIVERSITY
# ##COLLEGE OF COMPUTING AND INFORMATICS
# ###DEPARTMENT OF INFORMATION SYSTEMS
# ### COURSE OF ARTIFICIAL INTELLIGENCE
# ####PROJECT: GEEZ NUMBER PREDICTION
# #####GROUP 1 AND 12 MEMBER NAME
# #####1.Dejene Tolera
# #####2.Dheresa Amante
# #####3.Dendea Tarekegn
# #####4.Ebisa Edesa
# #####5.Deraro Birina
# #####6.Atinaf Lamesa

# %% [markdown]
# #GEEZ NUMBER PREDICTION
# Geez Number Prediction is in order to make a prediction, first Learning the  Machine or the Computer with a Dataset and second make test that, Machine or Computer is correctly train or not based on train_set and test_set with the geez number image from am_numbers, prediction and test directory.

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
classifier = Sequential()

classifier.add(Convolution2D(32,(3,3),padding='same', input_shape = (28, 28, 3), activation = 'relu', data_format='channels_last'))
classifier.add(MaxPooling2D(pool_size = (2,2)))
classifier.add(Convolution2D(64,(3,3),padding='same', activation = 'relu', data_format='channels_last'))
classifier.add(MaxPooling2D(pool_size = (2,2)))
#classifier.add(Dropout(0.25))

classifier.add(Flatten())
classifier.add(Dense(128, activation = 'relu'))
classifier.add(Dense(9, activation = 'softmax'))

classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# #Divide the Dataset into training_set and test_set.

# %%
datagen = ImageDataGenerator(rescale = 1./255,
                             validation_split=0.2,
                                shear_range=0.2,
                                zoom_range=0.2,
                                horizontal_flip=True)


training_set  = datagen.flow_from_directory('/content/drive/MyDrive/Geez Number Prediction/am_numbers',
                                        subset='training',
                                                   target_size=(28,28),
                                                   batch_size=32,
                                                   class_mode='categorical')
test_set  = datagen.flow_from_directory('/content/drive/MyDrive/Geez Number Prediction/am_numbers',
                                        subset='validation',
                                            target_size=(28,28),
                                                batch_size=32,
                                                class_mode='categorical')
# Out:
# Found 720 images belonging to 9 classes.
# Found 180 images belonging to 9 classes.

# %% [markdown]
# #Make the test_set with 20% of the Dataset from the Dataset.

# %%
img = load_img('/content/drive/MyDrive/Geez Number Prediction/am_numbers/1/3.jpg')  
x = img_to_array(img) 
x = x.reshape((1,) + x.shape) 


i = 0
for batch in datagen.flow(x, batch_size=1,
                          save_to_dir='/content/drive/MyDrive/Geez Number Prediction/test', save_prefix='dej', save_format='jpg'):
    i += 1
    if i > 20:
        break;

# %% [markdown]
# #Make Trainning the Computer or Machine by training_set with the geez number image from am_numbers directory.

# %%
classifier.fit(training_set,
                        epochs = 10,
                        
                        )
print("                    ")
print(" Trainning Dataset is Successfully")
# Out:
# Epoch 1/10
# 23/23 [==============================] - 4s 111ms/step - loss: 0.0763 - accuracy: 0.8871
# Epoch 2/10
# 23/23 [==============================] - 3s 106ms/step - loss: 0.0704 - accuracy: 0.9164
# Epoch 3/10
# 23/23 [==============================] - 3s 109ms/step - loss: 0.0650 - accuracy: 0.9204
# Epoch 4/10
# 23/23 [==============================] - 3s 111ms/step - loss: 0.0546 - accuracy: 0.9339
# Epoch 5/10
# 23/23 [==============================] - 3s 110ms/step - loss: 0.0522 - accuracy: 0.9476
# Epoch 6/10
# 23/23 [==============================] - 3s 112ms/step - loss: 0.0491 - accuracy: 0.9633
# Epoch 7/10
# 23/23 [==============================] - 3s 116ms/step - loss: 0.0432 - accuracy: 0.9417
# Epoch 8/10
# 23/23 [==============================] - 3s 108ms/step - loss: 0.0461 - accuracy: 0.9411
# Epoch 9/10
# 23/23 [==============================] - 3s 111ms/step - loss: 0.0333 - accuracy: 0.9757
# Epoch 10/10
# ...

# %% [markdown]
# #Make Predict the Geez Number to Numeric Number by get the geez image from the Prediction directory.

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

ima1 = cv2.imread('/content/drive/MyDrive/Geez Number Prediction/prediction/13.jpg')

ima1 = np.reshape(ima1,[1,28,28,3])

class1 = np.argmax(classifier.predict(ima1), axis=-1)


print(class1)
# Out:
# [8]
